# %% [markdown]
# # Assignment_WebScraping BeautifulSoup Evaluation

# %% [markdown]
# # 1) Write a python program to display IMDB’s Top rated 100 Indian movies’ data https://www.imdb.com/list/ls056092300/ (i.e. name, rating, year ofrelease) and make data frame.

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
import re
import warnings
warnings.filterwarnings('ignore')

# %%
def movies(url):
    response=requests.get(url)
    
    if response.status_code==200:
        print('Successful response\n','*'*25)
        
        msoup=bs(response.content)
        name=[]
        for i in msoup.find_all('h3',class_='lister-item-header'):
            ii=i.text.split('\n')[2]
            name.append(ii)
        
        rating=[]
        for j in msoup.find_all('div',class_="ipl-rating-star small"):
            jj=j.text.strip('\n')
            rating.append(jj)
    
        year=[]
        for k in msoup.find_all('span',class_="lister-item-year text-muted unbold"):
                kk=k.text.strip()
                res=re.findall(r'\d{4}', kk)
                year.append(res)
        if len(name)==len(rating)==len(year):
            print('Data is equal in all columns\n','*'*25)
            names=pd.DataFrame(name,columns=['Indian movie title'])
            ratings=pd.DataFrame(rating,columns=['Rating'])
            years=pd.DataFrame(year,columns=['Year of Release'])
            
            Indian_movies=pd.concat([names,ratings,years], axis=1)
            print('IMDB’s Top rated 100 Indian movies: \n')
            display(Indian_movies)
        else:
            print('Data is NOT equal in all columns')
    
    
    else:
        print('html response not successful')

# %%
movies(r'https://www.imdb.com/list/ls056092300/')
# Out:
# Successful response
#  *************************
# Data is equal in all columns
#  *************************
# IMDB’s Top rated 100 Indian movies:
#                    Indian movie title Rating Year of Release
# 0                     Ship of Theseus      8            2012
# 1                              Iruvar    8.4            1997
# 2                     Kaagaz Ke Phool    7.8            1959
# 3   Lagaan: Once Upon a Time in India    8.1            2001
# 4                     Pather Panchali    8.2            1955
# ..                                ...    ...             ...
# 95                        Apur Sansar    8.4            1959
# 96                        Kanchivaram    8.2            2008
# 97                    Monsoon Wedding    7.3            2001
# 98                              Black    8.1            2005
# 99                            Deewaar      8            1975
#
# [100 rows x 3 columns]

# %% [markdown]
# # 2) Write a python program to scrape product name, price and discounts from https://peachmode.com/search?q=bags

# %%
def peach(url):
    pdt=requests.get(r'https://peachmode.com/search?q=bags')
    if pdt.status_code==200:
        print('HTML response successful')
        psoup=bs(pdt.content,'html.parser')
        
        pdtname=[]
        pdtprice=[]
        pdtdisc=[]
        
        pdtdetails=psoup.find_all('div',class_='st-product st-col-xs-6 st-col-sm-3 st-col-md-3')
        if pdtdetails:
            for i in pdtdetails:
                ii=i.find('div',class_='product-title').find('a').find('span').text.strip()
                pdtname.append(ii)

                jj=i.find('span', class_='discounted_price').text.strip()
                pdtprice.append(jj)

        return pdtname, pdtprice
 

peach('https://peachmode.com/search?q=bags')
# Out:
# HTML response successful
# (['${ item.title }$'],
#  ['${currency }$${ numberWithComa(item.activeDiscountedPrice) }$'])

# %% [markdown]
# Data is getting scraped only in the form of placeholders.

# %% [markdown]
# # 3) Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape:
#
#
# a) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.
#
# b) Top 10 ODI Batsmen along with the records of their team and rating.
#
# c) Top 10 ODI bowlers along with the records of their team and rating.

# %% [markdown]
# a) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.

# %%
def odi1(url):
    odi1=requests.get(url)
    if odi1.status_code==200:
        print('Successful html response\n','*'*35)
        osoup1=bs(odi1.content,'html.parser')
        table_container1 = osoup1.find('div', class_='container')
        table_container2=osoup1.find('section', class_="container w-full")

        if table_container1 or table_container2:
            print('table_container found\n')
        
            table1=table_container1('div',class_='si-table-row')
            table2=table_container2('div',class_='si-table-row')
    
            if table1 or table2:
                print('table found')
    
        
            else:
                print('table NOT found')
        else:
            print('table_container NOT found')

odi1('https://www.icc-cricket.com/rankings/team-rankings/mens/odi')
# Out:
# Successful html response
#  ***********************************
# table_container found
#
# table NOT found

# %%
table_container1.text
# Out:
# "Exclusive content, priority ticket access and personalised news. Never miss a moment!Sign inHomeRankingsFixtures & ResultsNewsEventsMen's T20 World CupICC Cricket World Cup League 2Cricket World Cup Challenge League Play-off 2024U19 Cricket World CupICC Women's ChampionshipWorld Test ChampionshipCricket world cupAwardsvideosTeams100% CricketCrictosHall of FameCriiioAbout ICCMedia ReleasesPhotosCommercial OpportunitiesTravelENGLISHMatchesRankingsNewsAwardsTravelvideosSearchaccountlogout"

# %%
table_container2.text
# Out:
# "Jump toMen's Test Team RankingsMen's ODI Team RankingsMen's T20I Team RankingsMen's Test Batting RankingsMen's ODI Batting RankingsMen's T20I Batting RankingsMen's Test Bowling RankingsMen's ODI Bowling RankingsMen's T20I Bowling RankingsMen's Test All-Rounder RankingsMen's ODI All-Rounder RankingsMen's T20I All-Rounder RankingsWomen's T20I Team RankingsWomen's ODI Team RankingsWomen's T20I Batting RankingsWomen's ODI Batting RankingsWomens T20I Bowling RankingsWomens ODI Bowling RankingsWomen's T20I ALL-Rounder RankingsWomen's ODI ALL-Rounder RankingsICC World RankingsMen's Test Team RankingsMen's ODI Team RankingsMen's T20I Team RankingsMen's Test Batting RankingsMen's ODI Batting RankingsMen's T20I Batting RankingsMen's Test Bowling RankingsMen's ODI Bowling RankingsMen's T20I Bowling RankingsMen's Test All-Rounder RankingsMen's ODI All-Rounder RankingsMen's T20I All-Rounder RankingsWomen's T20I Team RankingsWomen's ODI Team RankingsWomen's T20I Batting RankingsWomen's ODI Battin
# ...

# %% [markdown]
# b) Top 10 ODI Batsmen along with the records of their team and rating.

# %%
def odi2(url):
    odi2=requests.get(url)
    if odi2.status_code==200:
        print('Successful html response\n','*'*35)
        osoup2=bs(odi2.content,'html.parser')
        table_container1 = osoup2.find('div', class_='container')
        table_container2=osoup2.find('section', class_="container w-full")

        if table_container1 or table_container2:
            print('table_container found\n')
        
            table1=table_container1('div',class_='si-table-row')
            table2=table_container2('div',class_='si-table-row')
    
            if table1 or table2:
                print('table found')
    
        
            else:
                print('table NOT found')
        else:
            print('table_container NOT found')
    else:
        print('html response unsuccessful\n')

odi1('https://www.icc-cricket.com/rankings/batting/mens/odi')
# Out:
# Successful html response
#  ***********************************
# table_container found
#
# table NOT found

# %% [markdown]
# c) Top 10 ODI bowlers along with the records of their team and rating.

# %%
def odi3(url):
    odi3=requests.get(url)
    if odi3.status_code==200:
        print('Successful html response\n','*'*35)
        osoup3=bs(odi3.content,'html.parser')
        table_container1 = osoup3.find('div', class_='container')
        table_container2=osoup3.find('section', class_="container w-full")

        if table_container1 or table_container2:
            print('table_container found\n')
        
            table1=table_container1('div',class_='si-table-row')
            table2=table_container2('div',class_='si-table-row')
    
            if table1 or table2:
                print('table found')
    
        
            else:
                print('table NOT found')
        else:
            print('table_container NOT found')
            
    else:
        print('html response unsuccessful\n')

odi1('https://www.icc-cricket.com/rankings/bowling/mens/odi')
# Out:
# Successful html response
#  ***********************************
# table_container found
#
# table NOT found

# %% [markdown]
# # 4) Write a python program to scrape details of all the posts from https://www.patreon.com/coreyms .
# Scrape the heading, date, content and the likes for the video from the link for the youtube video from the post.

# %%
def patreon(url):
    post=requests.get(url)
    if post.status_code==200:
        print('Successful html response\n','*'*35)
        sp=bs(post.content,'html.parser')
        postname=sp.find('p')
        if postname:
            print('Name of post extracted\n','*'*35,'\n',postname.text)
        else:
            print('Name of post NOT extracted')
            
        
        
        
patreon('https://www.patreon.com/coreyms')
# Out:
# Successful html response
#  ***********************************
# Name of post extracted
#  ***********************************
#  creating Programming Tutorials

# %%
def patreon(url):
    post=requests.get(url)
    if post.status_code==200:
        print('Successful html response\n','*'*35)
        sp=bs(post.content,'html.parser')
        postname=sp.find('a',href='/posts/how-to-use-as-83336794')
        if postname:
            print('Name of post extracted\n','*'*35,'\n',postname.text)
        else:
            print('Name of post NOT extracted')
            
        
        
        
patreon('https://www.patreon.com/coreyms')
# Out:
# Successful html response
#  ***********************************
# Name of post NOT extracted

# %%
def patreon(url):
    post=requests.get(url)
    if post.status_code==200:
        print('Successful html response\n','*'*35)
        sp=bs(post.content,'html.parser')
        postname=sp.find('div')
        if postname:
            print('Name of post extracted\n','*'*35,'\n',postname.text)
        else:
            print('Name of post NOT extracted')
            
        
        
        
patreon('https://www.patreon.com/coreyms')
# Out:
# Successful html response
#  ***********************************
# Name of post extracted
#  ***********************************
# ...

# %% [markdown]
# # 5) Write a python program to scrape house details from mentioned URL. It should include house title, location, area, EMI and price from https://www.nobroker.in/ .Enter three localities which are Indira Nagar, Jayanagar, Rajaji Nagar.

# %%
def house(url):
    p=requests.get(url)
    
    if p.status_code==200:
        print('Successful response\n','*'*35)
        
        hsoup=bs(p.content,'html.parser')
        
        title=[]
        location=[]
        area=[]
        rent=[]
        
        for i in hsoup.find_all('a',{'class': 'overflow-hidden overflow-ellipsis whitespace-nowrap max-w-80pe po:max-w-full'}):
                ii=i.get_text(strip=True)
                if ii:
                    title.append(ii)
                else:
                    title.append('NA')
                                
        for i in hsoup.find_all('a',{'class': 'overflow-hidden overflow-ellipsis whitespace-nowrap max-w-80pe po:max-w-full'}):
                ii=i.get_text()
                loc=re.search('Jaya ?nagar|Rajaji ?nagar|Indira ?nagar',ii,re.IGNORECASE)
                if loc:
                    location.append(loc.group())
                else:
                    location.append('NA')
                        
                                              
        for i in hsoup.find_all('div',class_='mt-0.5p overflow-hidden overflow-ellipsis whitespace-nowrap max-w-70 text-gray-light leading-4 po:mb-0.1p po:max-w-95'):
                ii=i.get_text(strip=True)
                if ii:
                    area.append(ii)
                else:
                    area.append('NA')
                          
            
        for i in hsoup.find_all('div',{'id':'minimumRent'}):
            ii=i.get_text(strip=True)
            iii=re.search(r'₹ *([\d,]+)',ii)
            if iii:
                rent.append(iii.group(1))
            else:
                rent.append('NA')
               
        titles=pd.DataFrame(title,columns=['House title'])
        locations=pd.DataFrame(location,columns=['House location'])
        Area=pd.DataFrame(area,columns=['House area'])
        Rent=pd.DataFrame(rent,columns=['House rent'])
            
        No_broker=pd.concat([titles,locations,Area,Rent], axis=1)
        print('House details from NoBroker: \n')
        display(No_broker)
    
  
    else:
        print('html response not successful')

# %%
house('https://www.nobroker.in/property/rent/bangalore/multiple?searchParam=...&radius=2.0&sharedAccomodation=0&city=bangalore&locality=Indiranagar,Jayanagar,Rajajinagar&isMetro=false')
# Out:
# Successful response
#  ***********************************
# House details from NoBroker:
#                                           House title House location  \
# 0                1 BHK House for Rent  In Rajajinagar    Rajajinagar
# 1   2 BHK Flat In Sas Residency Jayanagar for Rent...      Jayanagar
# 2                1 BHK House for Rent  In Rajajinagar    Rajajinagar
# 3                  3 BHK House for Rent  In Jayanagar      Jayanagar
# 4   3 BHK Flat In Ibbani Apartment for Rent  In Ja...      Jayanagar
# 5    2 BHK House for Rent  In Jayanagar 4th 't' Block      Jayanagar
# 6            1 RK House for Rent  In 12th B Main Road             NA
# 7        3 BHK House for Rent  In Jayanagar 5th Block      Jayanagar
# 8   3 BHK Flat In Standaloine Building for Rent  I...      Jayanagar
# 9           1 BHK Flat In Sb for Rent  In Rajajinagar    Rajajinagar
# 10    3 BHK House for Rent  In 723, 36th A Cross Road             NA
# ...

# %% [markdown]
# # 6) Write a python program to scrape first 10 product details which include product name , price , Image URL from https://www.bewakoof.com/bestseller?sort=popular .

# %%
def bwkf(url):
    k=requests.get(url)
    if k.status_code==200:
        print('HTML response successful!\n','*'*50)
        bsoup=bs(k.content,'html.parser')
        
        pdtname=[]
        pdtimg=[]
        pdtprice=[]
        
        for i in bsoup.find_all('div',class_='productNaming'):
            name=i.find('h2')
            if name:
                pdtname.append(name.text.strip())
                
        
        for i in bsoup.find_all('div',class_='discountedPriceText'):
            pdtprice.append(i.text)
        
        for i in bsoup.find_all('img',class_='productImgTag'):
            pdtimg.append(i['src'])
        
        pdtnames=pd.DataFrame(pdtname,columns=['Product name'])
        pdtprices=pd.DataFrame(pdtprice,columns=['Price'])
        pdtimgs=pd.DataFrame(pdtimg,columns=['Image url'])
        
        bewakoof=pd.concat([pdtnames,pdtprices,pdtimgs],axis=1)
        print('Product details of popular clothing from Bewakoof website: \n')
        return bewakoof
        
    else:
        print('HTML response not successful')

# %%
bwkf('https://www.bewakoof.com/bestseller?sort=popular')
# Out:
# HTML response successful!
#  **************************************************
# Product details of popular clothing from Bewakoof website:
#                                         Product name  Price  \
# 0                                Men's White T-shirt   ₹499
# 1  Women's Blue Round in Bugs Graphic Printed Ove...   ₹487
# 2                               Men's Black T-Shirts   ₹439
# 3                          Women's Brown Cargo Pants  ₹1299
# 4                                Men's Black T-shirt   ₹499
# 5  Men's Grey Eternity Graphic Printed Oversized ...   ₹649
# 6       Men's Black Eternity Graphic Printed T-shirt   ₹379
# 7                 Women's Black Straight Cargo Pants  ₹1499
# 8                  Women's Blue Straight Cargo Pants  ₹1299
# 9                      Men's Black Oversized T-shirt   ₹649
#
#                                            Image url
# 0  https://images.bewakoof.com/t640/men-s-white-t...
# 1  https://images.bewakoof.com/t640/women-s-blue-...
# ...

# %% [markdown]
# # 7) Please visit https://www.cnbc.com/world/?region=world and scrap- a) headings b) date c) News link

# %%
def cnbc(url):
    c=requests.get(url)
    if c.status_code==200:
        print('HTML response successful\n','-'*40)
        csoup=bs(c.content)
        
        heading=[]
        link=[]
        date=[]
        
        for i in csoup.find_all('div', class_='RiverHeadline-headline'):
            
            heading.append(i.text.strip())
            
            lk=i.find('a')['href']
            link.append(lk)
            
            dt=re.search(r'(\d{4}/\d{2}/\d{2})',lk)
            if dt:
                date.append(dt.group())
                
            headings=pd.DataFrame(heading,columns=['News heading'])
            links=pd.DataFrame(link,columns=['News link'])
            dates=pd.DataFrame(date,columns=['News date'])
            cnbc_news=pd.concat([headings,links,dates],axis=1)
        print('News details published in CNBC website this week: \n')
        return cnbc_news 
    else:
        print('HTML response NOT successful\n')

# %%
cnbc('https://www.cnbc.com/world/?region=world')
# Out:
# HTML response successful
#  ----------------------------------------
# News details published in CNBC website this week:
#                                          News heading  \
# 0   Russia says U.S. defended Kyiv too quickly aft...
# 1   Want to invest $10,000? Here are 5 ETFs to buy...
# 2   China's Xi meets U.S. executives as businesses...
# 3   Mumbai overtakes Beijing to become Asia's bill...
# 4   India's love for gold has done little for its ...
# 5   U.S. or Europe – where's best to invest? CNBC ...
# 6   Nvidia's partners and more: BofA picks key glo...
# 7   This small Southeast Asian country has 'engine...
# 8   Trump is selling $60 Bibles with 'God Bless th...
# 9   Class bullies may earn more in middle age, stu...
# 10  Asia stocks mixed as investors assess China, A...
# 11  China opens WTO dispute against U.S. subsidies...
# 12  Logistics companies scramble after bridge coll...
# 13  Cocoa is soaring to records. What it means for...
# ...

# %% [markdown]
# # 8) Please visit https://www.keaipublishing.com/en/journals/artificial-intelligence-in-agriculture/most-downloaded- articles/ and scrap- a) Paper title b) date c) Author

# %%
def keai(url):
    j=requests.get(url)
    if j.status_code==200:
        print('HTML response successful\n','-'*40)
        jsoup=bs(j.content)
        
        title=[]
        author=[]
        date=[]
        
        for i in jsoup.find_all('h2',class_='h5 article-title'):
            ii=i.get_text(strip=True)
            title.append(ii)
            
        for j in jsoup.find_all('p',class_='article-date'):
            date.append(j.text)
            
        for k in jsoup.find_all('p',class_='article-authors'):
            author.append(k.text.strip())
            
        if len(author)==len(title)==len(date):
                titles=pd.DataFrame(title,columns=['Article title'])
                authors=pd.DataFrame(author,columns=['Article authors'])
                dates=pd.DataFrame(date,columns=['Pulication date'])
                keai_journals=pd.concat([titles,authors,dates],axis=1)
                print('Most downloaded articles in "Artificial Intelligence in Agriculture" category: \n')
               
                return keai_journals
    
        else:
               print('Columns not equal in size')
    else:
               print('HTML response NOT successful\n')

# %%
keai('https://www.keaipublishing.com/en/journals/artificial-intelligence-in-agriculture/most-downloaded-articles/')
# Out:
# HTML response successful
#  ----------------------------------------
# Most downloaded articles in "Artificial Intelligence in Agriculture" category:
#                                         Article title  \
# 0   Implementation of artificial intelligence in a...
# 1   A comprehensive review on automation in agricu...
# 2               Review of agricultural IoT technology
# 3   Automation and digitization of agriculture usi...
# 4   Real-time hyperspectral imaging for the in-fie...
# 5   Applications of electronic nose (e-nose) and e...
# 6             Fruit ripeness classification: A survey
# 7   A review of imaging techniques for plant disea...
# 8   Deep learning based computer vision approaches...
# 9   Comparison of CNN-based deep learning architec...
# 10  Transfer Learning for Multi-Crop Leaf Disease ...
# 11  DeepRice: A deep learning and deep feature bas...
# 12  Plant disease detection using hybrid model bas...
# 13  How artificial intelligence uses to achieve th...
# ...
